# %% [markdown]
# # Week1 653380250-9 นายนวมินทร์ คำจันทร์

# %% [markdown]
# ## Lab1.1: Environment setup & first script.

# %%
print("Hello, Python Course!")
# Out:
# Hello, Python Course!

# %% [markdown]
# ## Lab1.2: Working with variable and basic data type.

# %% [markdown]
# ### 2. Declare and print variables:

# %%
age = 23
gpa = 3.99
favorite_color = "Blue"
student = True

print(f"Age = {type(age)}")
print(f"GPA = {type(gpa)}")
print(f"Favorite Color = {type(favorite_color)}")
print(f"Student = {type(student)}")
# Out:
# Age = <class 'int'>
# GPA = <class 'float'>
# Favorite Color = <class 'str'>
# Student = <class 'bool'>

# %% [markdown]
# ### 3. Perform simple arithmetic:

# %%
num1 = 7
num2 = 6
sum = num1 + num2
print("Sum = ",sum)
# Out:
# Sum =  13

# %% [markdown]
# ### 4. String concatenation and f-strings:

# %%
First_name = "Nawamin"
Last_name = "Comjun"
Full_name = First_name + " " + Last_name
print(f"Hello, {Full_name}")
# Out:
# Hello, Nawamin Comjun

# %% [markdown]
# ### 5. User input and type conversion:

# %%
num = input("What your favorite number : ")
print("type of A is : ", type(num))
num = int(num)
result = num + 5
print(num," + 5 = ", result)
# Out:
# type of A is :  <class 'str'>
# 4  + 5 =  9

# %% [markdown]
# ## Activity

# %% [markdown]
# ## Activity 1.1 Class discussion - use of scripting
